# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mohsennasab/python-fundamentals-hh/blob/main/notebooks/03_vector-data/03_01_introduction_to_vector_data.ipynb)

# %% [markdown]
# # Module 3, Lesson 1: Introduction to Vector Data
# ## Understanding Where Things Are and What They Affect
#
# ### Welcome to Spatial Analysis!
# This lesson introduces **vector (spatial) data analysis** - the foundation for understanding **where** things are in your H&H models. By the end, you'll confidently work with watersheds, infrastructure, and their spatial relationships.
#
# ### What You'll Work Through Today:
# - Understand vector data as "smart drawings" with attributes
# - Load and visualize watershed boundaries and building footprints
# - Master coordinate systems (CRS) for accurate analysis
# - Perform spatial operations (clip, intersect, buffer)
# - Answer engineering questions: "What's at risk?" "What's in this watershed?"
# - Create professional maps with labels and legends
#
# ### Module Structure:
# 1. **Mental Models** - How to think about spatial data
# 2. **Vector Data Basics** - Points, lines, polygons
# 3. **Loading Spatial Data** - GeoJSON vs Shapefiles
# 4. **Coordinate Systems** - Getting everything aligned
# 5. **Visualization** - Making meaningful maps
# 6. **Spatial Operations** - Engineering questions answered
# 7. **Real Analysis** - Buildings at risk in watersheds
# 8. **What You Can Now Do** - Your new spatial toolkit
#
# ---

# %% [markdown]
# ## A Quick Note on Using AI as You Learn
#
# As you work through this notebook, you'll run into code that looks unfamiliar. That's expected - spatial analysis introduces a bunch of new functions and concepts.
#
# When something doesn't make sense, pause and ask your AI assistant about it. Here are some things you might ask:
#
# - *"What does this code cell do, line by line?"*
# - *"Why do we need to reproject to EPSG:4326 before using Folium?"*
# - *"What would happen if I skipped this step?"*
# - *"Is there a simpler way to write this?"*
#
# You don't need to understand everything on the first pass. The more you ask, the faster things will click. Treat your AI like a patient coworker who's always happy to explain.

# %% [markdown]
# ## Part 1: Mental Models - Spatial Data for H&H Engineers
#
# ### Vector Data Answers Three Critical Questions:
#
# 1. **WHERE are things?** → Location on Earth
# 2. **WHAT belongs to what?** → Spatial relationships
# 3. **WHAT intersects/overlaps?** → Risk and impact zones
#
# ### Think of Vector Data as "Smart Drawings"
#
# **Traditional CAD/Drawing:**
# - Lines and shapes
# - Visual only
# - No real-world location
#
# **Vector Data (GIS):**
# - Lines and shapes WITH attributes
# - Each shape knows its real-world location
# - Each shape has a data table attached
# - Shapes can interact (clip, buffer, intersect)
#
# ### The Three Vector Types
#
# | Type | H&H Examples | What It Represents |
# |------|-------------|--------------------|
# | **Points** | Gauge stations, outfalls, wells | Specific locations |
# | **Lines** | Streams, pipes, channels | Linear features |
# | **Polygons** | Watersheds, buildings, flood zones | Areas/regions |
#
# ### Today's Engineering Scenario
#
# **Question:** "If this watershed floods, which buildings are at risk?"
#
# To answer this, we need:
# - Watershed boundaries (polygons)
# - Building footprints (polygons)
# - A way to find what's inside what (spatial operations)
#
# This is **screening-level analysis**. The type of fast, defensible analysis engineers do early in projects.
#
# ### Key Mindset:
# **Spatial operations are just filters with geography.** Instead of filtering by date or value, you're filtering by location.

# %% [markdown]
# ## Part 2: Setting Up Our Spatial Workspace
#
# ### Installing and Importing Libraries
#
# For spatial and geospatial analysis in Python, we need a few specialized libraries. You can think of libraries as toolboxes that give Python new capabilities.
#
# In this module, we will mainly use:
#
# - **GeoPandas** → for working with spatial datasets such as shapefiles and GeoJSON files
# - **Shapely** → for geometric operations such as creating buffers, measuring distances, and checking spatial relationships
# - **Folium** → for creating interactive web maps that you can zoom, pan, and explore
#
# These libraries are built on top of the regular `pandas` library you learned earlier, but they add spatial and mapping capabilities.
#
# ---
#
# ### GeoPandas
#
# `GeoPandas` is one of the most important Python libraries for GIS and spatial analysis.
#
# If you already know `pandas`, GeoPandas will feel familiar because it works in a similar way, but with geometry added.
#
# With GeoPandas, you can:
# - Read shapefiles and GeoJSON files
# - Store points, lines, and polygons
# - Plot static maps
# - Reproject spatial data
# - Filter spatial features
# - Perform spatial joins and overlays
# - Analyze watersheds, rivers, parcels, floodplains, and more
#
# You can think of GeoPandas as:
#
# > **Pandas + GIS capabilities**
#
# For example:
# - A regular pandas DataFrame stores rows and columns
# - A GeoPandas GeoDataFrame stores rows, columns, **and geometry**
#
# ---
#
# ### Shapely
#
# `Shapely` is the geometry engine behind many spatial operations in Python.
#
# It works directly with geometric shapes such as:
# - Points
# - Lines
# - Polygons
#
# Shapely allows you to:
# - Create buffers
# - Calculate areas and distances
# - Check if features intersect
# - Merge geometries
# - Clip geometries
# - Test spatial relationships
#
# For example:
# - “Does this stream intersect the floodplain?”
# - “Create a 500-foot buffer around the river”
# - “Calculate watershed area”
#
# These types of operations are powered by Shapely.
#
# ---
#
# ### Folium
#
# `Folium` is used to create **interactive maps** in Python.
#
# Unlike the static maps we create with `matplotlib`, Folium maps can be explored directly in the notebook. You can:
# - Zoom in and out
# - Pan around the map
# - Turn layers on and off
# - Add markers, popups, and tooltips
# - Display spatial data on top of web basemaps
#
# Folium is especially helpful when you want to visually inspect spatial data, share a quick interactive map, or explore where features are located.
#
# In this module, we will use Folium to create simple interactive maps of watersheds and building footprints.
#
# ---
#
# ### A Helpful Way to Think About It
#
# A simple way to think about these libraries is:
#
# - **Pandas** → tables and spreadsheets
# - **GeoPandas** → tables + spatial data
# - **Shapely** → geometry and spatial math
# - **Folium** → interactive web maps
#
# Together, these libraries form the foundation of many modern Python GIS and water resources workflows.

# %%
# Install spatial libraries (only needed once per session)
# !pip install -q geopandas folium

print("✅ Spatial libraries installed!")

# %%
# Import GeoPandas and give it the short name "gpd"
#
# GeoPandas is used for working with spatial and GIS data
# such as shapefiles, GeoJSON files, and map geometries
import geopandas as gpd

# Import pandas and give it the short name "pd"
#
# pandas is used for working with tables and tabular datasets
import pandas as pd

# Import folium
#
# folium is used for creating interactive maps
import folium

# Import matplotlib's plotting module and give it the short name "plt"
#
# matplotlib is used to create plots, charts, and maps
import matplotlib.pyplot as plt

# Import geometry tools from Shapely
#
# Point is used to create point geometries
# Polygon is used to create polygon geometries
from shapely.geometry import Point, Polygon

# Import Python's warnings module
#
# This module controls warning messages shown in the notebook
import warnings

# Hide warning messages to keep notebook output cleaner
#
# This is common in tutorials and demonstrations
warnings.filterwarnings('ignore')

# Set the default figure size for all plots
#
# figure.figsize controls:
# - width = 12 inches
# - height = 8 inches
plt.rcParams['figure.figsize'] = (12, 8)

# Print a confirmation message
print("Libraries imported successfully!")

# Print the installed version of GeoPandas
#
# __version__ is a built-in attribute that stores the package version
print(f"GeoPandas version: {gpd.__version__}")

# %% [markdown]
# ### Understanding Our Data Files
#
# We'll work with two Wyoming datasets:
#
# 1. **Building Footprints** (GeoJSON format)
#    - File: `Wyoming_building_footprint_Selected.geojson`
#    - Contains: Building polygons
#    - Use case: Infrastructure at risk
#
# 2. **Watershed Boundaries** (Shapefile in ZIP)
#    - File: `NHD__Watershed_Boundaries_HUC_12_Selected.zip`
#    - Contains: HUC-12 watershed polygons
#    - Use case: Drainage area analysis

# %% [markdown]
# ## Part 3: GeoJSON vs Shapefiles - Two Formats, Same Purpose
#
# ### Why Different Formats?
#
# **GeoJSON:**
# - Single text file
# - Human-readable
# - Web-friendly
# - Good for smaller datasets
#
# **Shapefile:**
# - Multiple files (.shp, .dbf, .shx, .prj)
# - Industry standard
# - More efficient for large data
# - Must be zipped for sharing
#
# ### Why Shapefiles Need ZIP Files
#
# A shapefile isn't one file - it's a family:
# - `.shp` - The geometry (shapes)
# - `.dbf` - The attributes (data table)
# - `.shx` - Index linking geometry to attributes
# - `.prj` - Coordinate system information
#
# **All must travel together**, hence the ZIP!
#
# ### Loading Data into Colab

# %%
# Import the file upload tool from Google Colab
#
# This allows users to upload files from their computer
from google.colab import files

# Print instructions for the user
print("📤 Please upload these files:")

# List the required files for this exercise
print("1. Wyoming_building_footprint_Selected.geojson")
print("2. NHD__Watershed_Boundaries_HUC_12_Selected.zip")

# Print an additional instruction message
print("\nClick 'Choose Files' below and select both files...")

# Open the file upload window
#
# A "Choose Files" button will appear in Colab
uploaded = files.upload()

# Print how many files were uploaded
#
# len(uploaded) counts the uploaded files
print(f"\n✅ Uploaded {len(uploaded)} files:")

# Loop through all uploaded file names
for filename in uploaded.keys():

    # Print the name of each uploaded file
    print(f"   - {filename}")

# %% [markdown]
# ## Part 4: Reading Vector Data - Your First Spatial DataFrames
#
# GeoPandas makes reading spatial data as easy as pandas!

# %%
# Read the GeoJSON file into a GeoPandas GeoDataFrame
#
# GeoJSON is a common spatial data format used to store:
# - Points
# - Lines
# - Polygons
# along with attribute data
print("Reading building footprints (GeoJSON)...")

# gpd.read_file() reads spatial data files
#
# The result is stored in a GeoDataFrame called "buildings"
buildings = gpd.read_file(
    'Wyoming_building_footprint_Selected.geojson'
)

# Print how many building features were loaded
#
# len(buildings) counts the number of rows/features
print(f"✅ Loaded {len(buildings)} building footprints")

# Print the column names in the dataset
#
# This helps us understand what attributes are available
print(f"Columns: {list(buildings.columns)}")

# Display the first 5 rows of the GeoDataFrame
#
# This allows us to preview the attribute data
# and geometry column
buildings.head()

# %%
# Read a Shapefile stored inside a ZIP file
#
# A Shapefile is a common GIS format used to store:
# - Points
# - Lines
# - Polygons
# along with attribute data
#
# Unlike GeoJSON, a Shapefile is actually made up
# of multiple files that work together.
print("Reading watershed boundaries (Shapefile in ZIP)...")

# GeoPandas can read directly from ZIP archives
#
# The "zip://" prefix tells GeoPandas
# that the shapefile is stored inside a ZIP file
#
# The result is stored in a GeoDataFrame
# called "watersheds"
watersheds = gpd.read_file(
    'zip://NHD__Watershed_Boundaries_HUC_12_Selected.zip'
)

# Print how many watershed polygons were loaded
#
# len(watersheds) counts the number of rows/features
print(f"✅ Loaded {len(watersheds)} HUC-12 watersheds")

# Print the column names in the dataset
#
# This helps us understand the available attributes
print(f"Columns: {list(watersheds.columns)}")

# Display the first 5 rows of the GeoDataFrame
#
# This lets us preview both the attribute data
# and the geometry column
watersheds.head()

# %% [markdown]
# ### Understanding the Data Structure
#
# A GeoDataFrame = DataFrame + Geometry Column
#
# Each row represents one feature (building or watershed) with:
# - **Attributes**: Regular columns (ID, name, area, etc.)
# - **Geometry**: Special column with the shape
#
# 🤖 **Try asking your AI assistant:** *"In a GeoDataFrame, what's the difference between the geometry column and the regular attribute columns? Why is geometry stored separately, and how is it represented under the hood?"*

# %%
# Explore the geometry types in the buildings dataset
#
# .geometry accesses the geometry column
# .type identifies the geometry type of each feature
# .value_counts() counts how many of each type exist
print("Building geometry types:")
print(buildings.geometry.type.value_counts())

# Print a blank line for cleaner output formatting
print("\nWatershed geometry types:")

# Explore the geometry types in the watershed dataset
#
# Common geometry types include:
# - Point
# - LineString
# - Polygon
# - MultiPolygon
print(watersheds.geometry.type.value_counts())

# Print a helpful interpretation message
#
# Polygon geometries represent enclosed areas,
# which makes them useful for:
# - Area calculations
# - Watershed analysis
# - Floodplain mapping
# - Spatial overlays
print("\n💡 Both are polygons - perfect for area calculations!")

# %% [markdown]
# ## Part 5: Coordinate Reference Systems (CRS) – Getting on the Same Page
#
# ### Why CRS Matters
#
# A **Coordinate Reference System (CRS)** defines how locations on the Earth are represented using coordinates.
#
# You can think of a CRS as the “language” a map uses to describe location and distance.
#
# Imagine two engineers working on the same project:
# - One measures locations in **latitude and longitude**
# - Another uses **feet or meters in a projected coordinate system**
#
# Even if they are mapping the exact same watershed, their coordinates will not line up correctly unless they use a common CRS.
#
# That’s why CRS is one of the most important concepts in GIS and spatial analysis.
#
# ---
#
# ### Geographic vs Projected CRS
#
# There are two major categories of CRS:
#
# ### Geographic CRS
# Uses:
# - Latitude
# - Longitude
# - Angular units (degrees)
#
# Example:
# - **WGS84 (EPSG:4326)**
#
# This is commonly used for:
# - GPS
# - Google Maps coordinates
# - Web mapping
# - Global datasets
#
# ⚠️ Important:
# Degrees are **not** true distance units, so calculations like:
# - Area
# - Distance
# - Buffer size
#
# can produce incorrect or confusing results.
#
# ---
#
# ### Projected CRS
# Uses:
# - Flat map coordinates
# - Linear units such as meters or feet
#
# Projected systems are better for:
# - Engineering calculations
# - Distance measurements
# - Area calculations
# - Hydraulic and hydrologic analysis
#
# Examples:
# - UTM
# - State Plane
# - Web Mercator
#
# ---
#
# ### Common CRS Types
#
# | CRS | EPSG Code | Units | Common Use |
# |-----|-----------|-------|-------------|
# | WGS84 | 4326 | Degrees | GPS, global maps |
# | Web Mercator | 3857 | Meters | Web maps (Google/Bing/OpenStreetMap) |
# | NAD83 UTM | Various | Meters | Regional engineering and mapping |
# | State Plane | Various | Feet or meters | Local engineering projects |
#
# ---
#
# ### Why This Matters in H&H
#
# CRS becomes especially important when:
# - Calculating watershed area
# - Measuring stream length
# - Creating buffers
# - Computing slope
# - Performing hydraulic analysis
# - Combining multiple datasets
#
# If the CRS is incorrect or inconsistent, the results can be completely wrong.
#
# For example:
# - Area calculations may appear tiny
# - Distances may not make sense
# - Layers may not align on the map
#
# ---
#
# ### 🤖 Try Asking Your AI Assistant
#
# ```text
# I have a GeoDataFrame in EPSG:4326 (latitude/longitude in degrees).
# When I calculate area using `.geometry.area`, the values are extremely small and do not match the real watershed area in square kilometers.
#
# Can you explain:
# 1. Why this happens
# 2. Why degrees are not appropriate for area calculations
# 3. What a projected CRS is
# 4. Which projected CRS would be appropriate for Wyoming
# 5. How to reproject my GeoDataFrame in GeoPandas before calculating area
#
# Please explain this in beginner-friendly language with example Python code.
# ```

# %%
# Check the Coordinate Reference System (CRS) of each dataset
#
# .crs stores information about the coordinate system
# used by the spatial dataset
print("Current Coordinate Reference Systems:")

# Print the CRS for the building footprints dataset
print(f"Buildings CRS: {buildings.crs}")

# Print the CRS for the watershed dataset
print(f"Watersheds CRS: {watersheds.crs}")

# Compare the two CRS definitions
#
# Spatial datasets should usually use the same CRS
# before performing:
# - spatial joins
# - overlays
# - distance calculations
# - area calculations
# - clipping operations
if buildings.crs == watersheds.crs:

    # Print a success message if both CRS match
    print("\n✅ Great! Both datasets use the same CRS")

else:

    # Print a warning if the CRS are different
    #
    # In this case, one dataset usually needs
    # to be reprojected before analysis
    print("\n⚠️ Different CRS detected - we need to align them!")

# %%
# Convert both datasets to a common projected CRS
#
# A projected CRS is important for:
# - Area calculations
# - Distance measurements
# - Buffer operations
# - Engineering analysis
#
# EPSG:32613 corresponds to:
# WGS 84 / UTM Zone 13N
#
# This CRS is a good choice for Wyoming because:
# - It is designed for this geographic region
# - It uses meters as units
# - It minimizes spatial distortion locally

target_crs = 'EPSG:32613'

# Print a message showing the CRS conversion
print(f"Converting to {target_crs} (UTM Zone 13N - meters)...")

# Reproject the buildings dataset into the target CRS
#
# .to_crs() creates a new GeoDataFrame
# with transformed coordinates
buildings_utm = buildings.to_crs(target_crs)

# Reproject the watershed dataset into the same CRS
watersheds_utm = watersheds.to_crs(target_crs)

# Print a success message
print("✅ Both datasets now in the same coordinate system!")

# Print useful information about the new CRS
print(f"   Units: meters")
print(f"   Good for: area calculations, distance measurements")

# %% [markdown]
# ## Part 6: Visualizing Vector Data - Making Maps That Communicate
#
# ### Basic Visualization
#
# Let's start with a simple map showing our data:
#
# #### Plotting Watersheds and Building Footprints
#
# The following code cell creates a simple map to visualize watershed boundaries and building locations together.
#
# First, a Matplotlib figure and axis are created with a larger figure size to make the map easier to read. The watershed polygons are plotted first using a light blue fill and dark blue outlines so they form the background context of the map. Plotting larger features first helps keep them from covering smaller details.
#
# Next, building footprints are plotted on top of the watersheds in red. A small marker size and partial transparency are used so dense areas of buildings remain visible without overwhelming the map.
#
# The map is then labeled with a title and axis labels showing UTM coordinates (easting and northing). A light grid is added to help with spatial reference.
#
# Finally, a small text box is placed in the upper-left corner of the map that reports the total number of buildings and watersheds shown. The layout is adjusted to avoid overlapping elements, and the figure is displayed.

# %%
# Create a figure and plotting area
#
# figsize controls the size of the map:
# - 14 = width
# - 10 = height
fig, ax = plt.subplots(figsize=(14, 10))

# Plot the watershed polygons first
#
# We usually plot larger background features first
# so smaller features can appear on top
watersheds_utm.plot(

    # Draw the map on the axes object "ax"
    ax=ax,

    # Fill color of the watershed polygons
    color='lightblue',

    # Color of polygon boundaries
    edgecolor='darkblue',

    # Thickness of watershed boundaries
    linewidth=1.5,

    # Transparency level
    #
    # alpha ranges from:
    # 0 = fully transparent
    # 1 = fully opaque
    alpha=0.5
)

# Plot building footprints on top of the watersheds
#
# Smaller features are usually plotted later
# so they remain visible
buildings_utm.plot(

    # Draw on the same axes
    ax=ax,

    # Color of building footprints
    color='red',

    # Size of plotted features
    markersize=0.5,

    # Transparency level
    alpha=0.6
)

# Add a title to the map
#
# fontsize controls text size
# fontweight='bold' makes the title bold
plt.title(
    'Wyoming Watersheds and Building Footprints',
    fontsize=16,
    fontweight='bold'
)

# Add a label to the x-axis
#
# Easting refers to the horizontal coordinate
# in a projected coordinate system
plt.xlabel('Easting (m)', fontsize=12)

# Add a label to the y-axis
#
# Northing refers to the vertical coordinate
# in a projected coordinate system
plt.ylabel('Northing (m)', fontsize=12)

# Turn on grid lines
#
# alpha controls grid transparency
plt.grid(True, alpha=0.3)

# Add a text box with summary information
#
# transform=ax.transAxes means:
# coordinates are based on the figure itself
# where:
# (0,0) = bottom-left
# (1,1) = top-right
plt.text(

    # Text box location inside the figure
    0.02,
    0.98,

    # Text content
    f'Total Buildings: {len(buildings_utm):,}\n'
    f'Total Watersheds: {len(watersheds_utm)}',

    # Use axes-relative coordinates
    transform=ax.transAxes,

    # Font size
    fontsize=10,

    # Align text from the top
    verticalalignment='top',

    # Create a background box behind the text
    bbox=dict(
        boxstyle='round',
        facecolor='wheat',
        alpha=0.8
    )
)

# Automatically adjust spacing in the figure
plt.tight_layout()

# Display the final map
plt.show()

# %% [markdown]
# ### Adding Labels to Watersheds
#
# For engineering communication, we often need to label features:

# %%
# Explore the attribute columns in the watershed dataset
#
# Attribute columns contain information associated
# with each watershed feature, such as:
# - watershed name
# - HUC code
# - area
# - state
# - drainage information
#
# We often inspect these columns before:
# - labeling maps
# - filtering data
# - performing analysis
print("Watershed attributes available for labeling:")

# Loop through all column names in the GeoDataFrame
for col in watersheds_utm.columns:

    # Skip the geometry column
    #
    # The geometry column contains spatial shapes,
    # not descriptive attribute information
    if col != 'geometry':

        # Print:
        # - the column name
        # - an example value from the first row
        #
        # .iloc[0] selects the first row value
        print(f"  - {col}: {watersheds_utm[col].iloc[0]}")

# %%
# Create a figure and plotting area
#
# figsize controls the width and height of the map
fig, ax = plt.subplots(figsize=(16, 12))

# Plot the watershed polygons
watersheds_utm.plot(

    # Draw the map on the axes object
    ax=ax,

    # Fill color of the watershed polygons
    color='lightblue',

    # Color of watershed boundaries
    edgecolor='darkblue',

    # Thickness of polygon boundaries
    linewidth=2,

    # Transparency level
    alpha=0.5
)

# Loop through each watershed feature (row)
#
# iterrows() lets us access:
# - the row index
# - the row data
for idx, row in watersheds_utm.iterrows():

    # Calculate the centroid (center point)
    # of the watershed polygon
    #
    # The centroid is often used for placing labels
    centroid = row.geometry.centroid

    # Determine which column to use for labels
    #
    # Some datasets may use lowercase "huc12"
    # while others may use uppercase "HUC12"
    if 'huc12' in row.index:

        # Use the lowercase HUC12 column
        label = row['huc12']

    elif 'HUC12' in row.index:

        # Use the uppercase HUC12 column
        label = row['HUC12']

    else:

        # If no HUC12 field exists,
        # create a simple fallback label
        label = f"WS-{idx+1}"

    # Add a label to the map
    #
    # annotate() places text at a specific location
    ax.annotate(

        # Text to display
        label,

        # Location of the label
        xy=(centroid.x, centroid.y),

        # Horizontally center the text
        ha='center',

        # Font size
        fontsize=8,

        # Make the label bold
        fontweight='bold',

        # Text color
        color='darkblue',

        # Add a white background box behind the text
        bbox=dict(
            boxstyle='round,pad=0.3',
            facecolor='white',
            alpha=0.8
        )
    )

# Add a title to the map
plt.title(
    'HUC-12 Watersheds with Labels',
    fontsize=16,
    fontweight='bold'
)

# Add an x-axis label
plt.xlabel('Easting (m)', fontsize=12)

# Add a y-axis label
plt.ylabel('Northing (m)', fontsize=12)

# Turn on grid lines
plt.grid(True, alpha=0.3)

# Automatically adjust spacing in the figure
plt.tight_layout()

# Display the final map
plt.show()

# %% [markdown]
# ## Part 7: Spatial Operations - Answering Engineering Questions
#
# ### The Engineering Question
#
# **"If HUC-12 watershed 101900090108 floods, which buildings are at risk?"**
#
# To answer this, we need to:
# 1. Find the specific watershed
# 2. Clip buildings to that watershed
# 3. Count and analyze affected buildings
#
# ### Step 1: Find Our Target Watershed
#
# 🤖 **Try asking your AI Assistant:** *"Show me the difference between `gpd.clip()`, `gpd.sjoin()`, and `gpd.overlay()` in plain English. When would I use each one for an H&H problem like 'which structures fall inside a watershed'?"*

# %%
# Define the HUC-12 code we want to find
#
# HUC stands for Hydrologic Unit Code.
# A HUC-12 represents a relatively small watershed unit.
target_huc = '101900090108'

# Find the watershed that matches the target HUC-12 code
#
# Different datasets may use different column names
# for HUC codes, such as:
# - huc12
# - HUC12
# - HUC_12
# - huc_12
#
# We will search the column names to find one
# that contains "huc".
huc_column = None

# Loop through all columns in the watershed GeoDataFrame
for col in watersheds_utm.columns:

    # Convert the column name to lowercase
    # and check whether it contains "huc"
    if 'huc' in col.lower():

        # Store the matching column name
        huc_column = col

        # Stop searching after the first match is found
        break

# Check whether a HUC column was found
if huc_column:

    # Print the name of the column that contains HUC values
    print(f"Found HUC column: {huc_column}")

    # Filter the watershed dataset to find the target HUC-12
    #
    # This keeps only rows where the HUC column
    # matches the target_huc value
    target_watershed = watersheds_utm[
        watersheds_utm[huc_column] == target_huc
    ]

    # Check whether the target watershed was found
    if len(target_watershed) > 0:

        # Print a success message
        print(f"✅ Found watershed {target_huc}")

    else:

        # If the target HUC was not found,
        # use the first watershed as an example
        print(
            f"⚠️ Watershed {target_huc} not found. "
            f"Using first watershed as example."
        )

        # .iloc[[0]] keeps the first row as a GeoDataFrame
        target_watershed = watersheds_utm.iloc[[0]]

else:

    # If no HUC column was found,
    # use the first watershed as an example
    print("⚠️ No HUC column found. Using first watershed as example.")

    # .iloc[[0]] selects the first watershed
    # while keeping the result as a GeoDataFrame
    target_watershed = watersheds_utm.iloc[[0]]

# Display attribute information for the selected watershed
print(f"\nTarget watershed info:")

# Loop through all columns in the selected watershed
for col in target_watershed.columns:

    # Skip the geometry column because it contains the polygon shape,
    # not a simple descriptive attribute
    if col != 'geometry':

        # Print the column name and its value
        #
        # .values[0] gets the value from the first selected row
        print(f"  {col}: {target_watershed[col].values[0]}")

# %% [markdown]
# ### Step 2: Clip Buildings to Watershed
#
# This is the spatial equivalent of filtering - keep only buildings inside the watershed:

# %%
# Perform a spatial clip operation
#
# A spatial clip keeps only the features
# that fall inside a boundary polygon.
#
# In this example:
# - buildings_utm = all building footprints
# - target_watershed = the watershed boundary
#
# The result will contain only buildings
# located inside the watershed.

# Print the number of buildings before clipping
#
# :, adds commas for readability
print(f"Total buildings before clip: {len(buildings_utm):,}")

# Perform the spatial clip operation
#
# gpd.clip() trims the building dataset
# to the extent of the target watershed
#
# Only buildings inside the watershed
# will remain in the output
buildings_in_watershed = gpd.clip(
    buildings_utm,
    target_watershed
)

# Print the number of buildings after clipping
print(f"Buildings within watershed: {len(buildings_in_watershed):,}")

# Print a simple interpretation message
#
# In real H&H or flood risk studies,
# these buildings could represent:
# - structures within a drainage area
# - potentially exposed assets
# - buildings affected by flooding
print(
    f"\n🎯 {len(buildings_in_watershed):,} "
    f"buildings potentially at risk!"
)

# %% [markdown]
# ### Step 3: Visualize the Results

# %%
# Create a figure with two maps side by side
#
# 1 row, 2 columns means:
# - ax1 will be the left map
# - ax2 will be the right map
#
# figsize controls the overall figure size
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8))

# =============================================================================
# LEFT MAP: OVERVIEW
# This map shows the target watershed in the context
# of the surrounding watersheds and buildings.
# =============================================================================

# Plot all watersheds in the background
#
# These provide geographic context
watersheds_utm.plot(
    ax=ax1,
    color='lightgray',
    edgecolor='gray',
    alpha=0.5
)

# Plot the selected target watershed on top
#
# The thicker dark blue boundary helps it stand out
target_watershed.plot(
    ax=ax1,
    color='lightblue',
    edgecolor='darkblue',
    linewidth=3
)

# Plot all buildings in the full dataset
#
# These are shown lightly in gray
# so they provide context without overwhelming the map
buildings_utm.plot(
    ax=ax1,
    color='gray',
    markersize=0.1,
    alpha=0.3
)

# Plot only the buildings inside the target watershed
#
# These are highlighted in red
buildings_in_watershed.plot(
    ax=ax1,
    color='red',
    markersize=1
)

# Add title and axis labels to the overview map
ax1.set_title(
    'Overview: Target Watershed in Context',
    fontsize=14,
    fontweight='bold'
)
ax1.set_xlabel('Easting (m)')
ax1.set_ylabel('Northing (m)')

# Turn on grid lines for the overview map
ax1.grid(True, alpha=0.3)

# =============================================================================
# RIGHT MAP: ZOOMED-IN VIEW
# This map focuses only on the target watershed
# and the buildings located inside it.
# =============================================================================

# Plot the target watershed boundary
target_watershed.plot(
    ax=ax2,
    color='lightblue',
    edgecolor='darkblue',
    linewidth=2,
    alpha=0.5
)

# Plot the buildings inside the target watershed
buildings_in_watershed.plot(
    ax=ax2,
    color='red',
    markersize=2
)

# Get the bounding box of the target watershed
#
# total_bounds returns:
# minx, miny, maxx, maxy
#
# These represent the left, bottom, right, and top
# coordinate limits of the watershed
minx, miny, maxx, maxy = target_watershed.total_bounds

# Set the x-axis limits for the zoomed map
#
# We add 1000 meters of padding around the watershed
# so the map does not feel too tightly cropped
ax2.set_xlim(minx - 1000, maxx + 1000)

# Set the y-axis limits for the zoomed map
ax2.set_ylim(miny - 1000, maxy + 1000)

# Add title and axis labels to the zoomed map
#
# The title includes the number of buildings
# found inside the watershed
ax2.set_title(
    f'Buildings at Risk: {len(buildings_in_watershed):,} structures',
    fontsize=14,
    fontweight='bold'
)
ax2.set_xlabel('Easting (m)')
ax2.set_ylabel('Northing (m)')

# Turn on grid lines for the zoomed map
ax2.grid(True, alpha=0.3)

# Add one overall title for the entire figure
plt.suptitle(
    'Flood Risk Analysis: Buildings in Watershed',
    fontsize=16,
    fontweight='bold'
)

# Automatically adjust spacing so titles and labels fit well
plt.tight_layout()

# Display the final figure
plt.show()

# %% [markdown]
# 🤖 **Try asking your AI Assistsnt:** *"How do I add a north arrow and a simple scale bar to a GeoPandas + matplotlib map? Show me the smallest change to the cell above."*

# %% [markdown]
# ## Part 8: Geometry Calculations - Quantifying Risk 📊
#
# ### Calculate Areas and Statistics

# %%
# Calculate the area of the target watershed
#
# Because we reprojected the data to UTM,
# the area is calculated in square meters
watershed_area_m2 = target_watershed.geometry.area.values[0]

# Convert watershed area from square meters to square kilometers
#
# 1 square kilometer = 1,000,000 square meters
watershed_area_km2 = watershed_area_m2 / 1_000_000

# Convert watershed area from square kilometers to square miles
#
# 1 square kilometer = 0.386102 square miles
watershed_area_mi2 = watershed_area_km2 * 0.386102

# Print a section title
print("WATERSHED STATISTICS")

# Print a separator line
print("=" * 40)

# Print watershed area in both metric and U.S. customary units
print(
    f"Area: {watershed_area_km2:.2f} km² "
    f"({watershed_area_mi2:.2f} mi²)"
)

# Print the number of buildings inside the watershed
print(f"Buildings at risk: {len(buildings_in_watershed):,}")

# Calculate and print building density
#
# This tells us how many buildings are located
# within each square kilometer of watershed area
print(
    f"Building density: "
    f"{len(buildings_in_watershed) / watershed_area_km2:.1f} buildings/km²"
)

# Calculate building footprint statistics only if buildings exist
#
# This prevents errors if no buildings were found
# inside the watershed
if len(buildings_in_watershed) > 0:

    # Calculate the area of each building footprint
    #
    # Since the data is in UTM meters,
    # the result is in square meters
    building_areas = buildings_in_watershed.geometry.area

    # Print a section title
    print("\nBUILDING FOOTPRINT STATISTICS")

    # Print a separator line
    print("=" * 40)

    # Calculate and print the total building footprint area
    #
    # 1 hectare = 10,000 square meters
    print(
        f"Total footprint area: "
        f"{building_areas.sum() / 10000:.2f} hectares"
    )

    # Calculate and print the average building footprint size
    print(f"Average building size: {building_areas.mean():.1f} m²")

    # Print the largest building footprint area
    print(f"Largest building: {building_areas.max():.1f} m²")

    # Print the smallest building footprint area
    print(f"Smallest building: {building_areas.min():.1f} m²")

# %% [markdown]
# 🤖 **Try asking your AI Assistant:**
#
# Before asking your AI assistant, copy and paste the relevant code cells above into the chat so the assistant understands:
# - what data you are working with
# - what variables already exist
# - and what your workflow looks like
#
# It also helps to mention that you want the solution written so it can run in **a single Google Colab code cell**.
#
# Try this prompt:
#
# ```text
# I am working in Google Colab. Here is my existing code and GeoDataFrame setup:
#
# [paste your previous code here]
#
# Using the `buildings_in_watershed` GeoDataFrame, write Python code that:
#
# 1. Creates a new column called `area_m2` containing the footprint area of each building in square meters
# 2. Sorts the buildings from largest to smallest footprint area
# 3. Displays the top 10 largest buildings as a GeoDataFrame
# 4. Creates a simple map highlighting these 10 largest buildings in a different color
# 5. Includes beginner-friendly comments explaining each step
#
# Please write the solution so it can run in a single Google Colab code cell.
# ```
#
# 💡 *Bonus question to ask your AI assistant:*
#
# ```text
# Why is it important that the GeoDataFrame is in a projected CRS before calculating building areas?
# ```

# %% [markdown]
# ## Part 9: Interactive Mapping - Web-Based Visualization
#
# For presentations and reports, interactive maps are powerful:
#
# The following code cell creates an interactive web map showing a target watershed and the buildings located within it.
#
# Because web maps require latitude and longitude coordinates, both the watershed and building datasets are first reprojected to WGS84 (EPSG:4326). The centroid of the watershed is then calculated and used to center the map.
#
# A Folium map is created using OpenStreetMap tiles and an initial zoom level appropriate for neighborhood-scale viewing. The watershed boundary is added as a GeoJSON layer with a light blue fill and darker outline to clearly define its extent. A tooltip is included so users can identify the watershed when hovering.
#
# Building footprints are added on top of the watershed in red. To keep the map responsive, buildings are only plotted if the total count is below a set threshold. Each building is styled with partial transparency so overlapping footprints remain visible.
#
# Finally, a title is added to the map using custom HTML, a summary message is printed to confirm how many buildings were included, and the interactive map object is displayed.

# %%
# Create an interactive map using Folium
#
# Folium creates web-style interactive maps that can be:
# - zoomed
# - panned
# - explored directly in Google Colab

# Convert both datasets to latitude/longitude coordinates
#
# Folium and most web maps use EPSG:4326
# which stores coordinates as:
# - latitude
# - longitude
#
# Our original datasets are in UTM meters,
# which are better for calculations but not for web mapping.
target_watershed_wgs = target_watershed.to_crs('EPSG:4326')
buildings_in_watershed_wgs = buildings_in_watershed.to_crs('EPSG:4326')

# Calculate the center point of the watershed
#
# This will be used as the starting center of the map
center_lat = target_watershed_wgs.geometry.centroid.y.values[0]
center_lon = target_watershed_wgs.geometry.centroid.x.values[0]

# Create the base interactive map
#
# location sets the center of the map
# zoom_start controls the initial zoom level
# tiles='OpenStreetMap' adds the OpenStreetMap basemap
m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=13,
    tiles='OpenStreetMap'
)

# Add the watershed boundary to the map
#
# We pass only the geometry column to avoid JSON serialization issues
folium.GeoJson(

    # Watershed polygon geometry
    target_watershed_wgs.geometry,

    # Define the watershed appearance
    style_function=lambda x: {
        'fillColor': 'lightblue',   # Interior fill color
        'color': 'darkblue',        # Boundary color
        'weight': 3,                # Boundary thickness
        'fillOpacity': 0.2          # Transparency
    },

    # Tooltip shown when hovering over the watershed
    tooltip="Target Watershed"

).add_to(m)

# Add building footprints to the map
folium.GeoJson(

    # Building footprint geometries
    buildings_in_watershed_wgs.geometry,

    # Name shown in the layer control
    name="Buildings in Watershed",

    # Define building appearance
    style_function=lambda x: {
        'fillColor': 'red',         # Building fill color
        'color': 'darkred',         # Building outline color
        'weight': 1,                # Outline thickness
        'fillOpacity': 0.8          # Transparency
    },

    # Tooltip shown when hovering over buildings
    tooltip="Building Footprint"

).add_to(m)

# Zoom the map to the watershed boundary
#
# total_bounds returns:
# minx, miny, maxx, maxy
#
# fit_bounds automatically zooms the map
# so the watershed fits nicely on screen
minx, miny, maxx, maxy = target_watershed_wgs.total_bounds

m.fit_bounds([
    [miny, minx],
    [maxy, maxx]
])

# Add a layer control button to the map
#
# This allows users to toggle layers on and off
folium.LayerControl().add_to(m)

# Print a confirmation message
print(
    f"Interactive map created with "
    f"{len(buildings_in_watershed_wgs):,} buildings"
)

# Display the interactive map
m

# %% [markdown]
# ## Practice Exercises 🎯
#
# Now it's your turn! Complete these exercises to reinforce your learning.
#
# ### Exercise 1: Watershed Area Ranking
# Calculate the area of all watersheds and identify the three largest.

# %%
# EXERCISE 1: Find the three largest watersheds
# Your code here:

# Step 1: Calculate area for all watersheds

# Step 2: Sort by area

# Step 3: Display top 3

# %% [markdown]
# ### Exercise 2: Multi-Watershed Analysis
# Select 3 watersheds and count buildings in each.

# %%
# EXERCISE 2: Analyze buildings in multiple watersheds
# Your code here:

# Step 1: Select 3 watersheds

# Step 2: For each watershed, clip buildings and count

# Step 3: Create a summary table

# %% [markdown]
# ### Exercise 3: Buffer Analysis
# Create a 500m buffer around buildings and see which watersheds they intersect.

# %%
# EXERCISE 3: Buffer analysis
# Your code here:

# Step 1: Select a few buildings

# Step 2: Create 500m buffers

# Step 3: Find intersecting watersheds

# %% [markdown]
# ### Exercise 4: Professional Map
# Create a publication-ready map with legend, scale bar, and north arrow.

# %%
# EXERCISE 4: Create a professional map
# Your code here:

# Include:
# - Title
# - Legend
# - Scale information
# - Color scheme
# - Labels

# %% [markdown]
# ### Exercise 5: Debug This Snippet with AI 🔍
#
# The function in the next cell is supposed to return a watershed's area in km^2. It runs without crashing, but the answer it returns is dramatically wrong. This is a very common spatial-analysis pitfall.
#
# Run the cell, see how big the gap is between the buggy and correct answers, then paste the function into your AI assistant with a clear question. The goal of this exercise is to practice the **run, observe, paste, ask, fix** loop you'll use every day in real work.
#
# **Suggested AI prompt:**
#
# > *"Here is a Python function and what it produced. It's supposed to return a watershed area in km^2, but the number is far smaller than the real area. Find the bug and show me a fixed version with a short explanation.*
# > *```
# > def buggy_watershed_area_km2(gdf_row):
# >     return gdf_row.geometry.area / 1_000_000
# > ```*
# > *Input GeoDataFrame CRS: EPSG:4326."*

# %%
# === Exercise 5: Debug This Snippet with AI ===
#
# The function below is meant to return a watershed area in square kilometers.
# It runs without error, but the value is far smaller than the real area.
# Run this cell, look at the two numbers, then paste the function into your
# AI assistant with the prompt above to find and fix the bug.

def buggy_watershed_area_km2(gdf_row):
    """Return the area of a watershed polygon in km^2."""
    return gdf_row.geometry.area / 1_000_000   # the bug lives on this line


# Compare the buggy result to a properly reprojected calculation.
# `watersheds` was loaded earlier in WGS84 (EPSG:4326, degrees), and `watersheds_utm`
# was reprojected to a projected CRS (EPSG:32613, meters) in Part 5.
example_row     = watersheds.iloc[0]
example_row_utm = watersheds_utm.iloc[0]

buggy_km2   = buggy_watershed_area_km2(example_row)
correct_km2 = example_row_utm.geometry.area / 1_000_000

print(f"Buggy function returns:  {buggy_km2:.8f} km^2")
print(f"Correct (UTM Zone 13N):  {correct_km2:.2f} km^2")
print()
print("The buggy result is orders of magnitude smaller than the correct one.")
print("Hint: what are the units of `.area` when a GeoDataFrame is in a geographic CRS?")

# %% [markdown]
# ## That's Module 3 Done!
#
# You just went from zero spatial analysis to clipping buildings by watershed, calculating areas, and building interactive maps. That's a solid day's work.
#
# ### What you can do now:
#
# **Data Management** - Load GeoJSON and Shapefiles, understand vector data structures, handle different coordinate systems
#
# **Spatial Analysis** - Clip features by boundaries, calculate areas and distances, create buffers, do spatial joins
#
# **Visualization** - Create static maps with matplotlib, add labels, build interactive web maps with Folium
#
# **Engineering Applications** - Identify infrastructure at risk, calculate watershed statistics, perform screening-level assessments
#
# ### Key things to remember:
#
# 1. **Vector data = smart drawings with data tables** - every shape carries attributes
# 2. **CRS alignment is critical** - always check that your layers are in the same coordinate system before doing any spatial operation
# 3. **Spatial operations are just geographic filters** - instead of filtering by date or value, you're filtering by location
# 4. **Start simple, build complexity** - get the basic clip working before adding fancy visualizations
#
# ### Quick reference:
#
# ```python
# gpd.read_file()          # Load data
# gdf.to_crs()            # Align coordinates
# gpd.clip()              # Clip by boundary
# gdf.buffer()            # Create buffers
# gdf.overlay()           # Intersect/union
# gdf.plot()              # Visualize
# gdf.geometry.area       # Calculate area
# ```
#
# ### What's next
#
# In Module 4, we'll bring in raster data (DEMs, land cover grids) and combine them with these vector boundaries. That's where things get really interesting for H&H work - you'll be able to answer questions about terrain, slopes, and land use within your watersheds.
